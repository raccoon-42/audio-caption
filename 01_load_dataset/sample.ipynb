# %%
from datasets import load_from_disk

ds = load_from_disk("./musiccaps/dataset_audio")
sample = ds[0]

# %%
print(sample.keys())
# Out:
# dict_keys(['ytid', 'start_s', 'end_s', 'audioset_positive_labels', 'aspect_list', 'caption', 'author_id', 'is_balanced_subset', 'is_audioset_eval', 'audio'])

# %%
caption = sample["caption"]
print(caption)
# Out:
# The male mid to high range voice sings loudly and full of emotions pouring out of his soul while strumming some minor chords on the guitar. This recording is of poor quality. This song may be played in an open mic, poetry bar.

# %%
audio = sample["audio"]

waveform = audio["array"]
sr = audio["sampling_rate"]

# %%
from IPython.display import Audio

audio = sample["audio"]

Audio(
    data=audio["array"],
    rate=audio["sampling_rate"]
)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample2 = ds[94]
caption = sample2["caption"]
print(caption)

audio = sample2["audio"]

Audio(
    data=audio["array"],
    rate=audio["sampling_rate"]
)
# Out:
# A female vocalist sings this pop song. The tempo is fast with a lively piano accompaniment, funky bass lines, violin harmony, synthesiser and electronic arrangements and punchy drumming. The song is youthful, romantic, warm, simple and groovy. This song is an Electro Pop/ Dance pop.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from datasets import load_from_disk

ds = load_from_disk("./musiccaps/dataset_audio")
sample = ds[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from datasets import load_from_disk
# ----> 3 ds = load_from_disk("./musiccaps/dataset_audio")
#       4 sample = ds[0]
#
# File ~/miniconda3/envs/audio-caption/lib/python3.10/site-packages/datasets/load.py:1471, in load_from_disk(dataset_path, keep_in_memory, storage_options)
#    1469 fs, *_ = url_to_fs(dataset_path, **(storage_options or {}))
#    1470 if not fs.exists(dataset_path):
# -> 1471     raise FileNotFoundError(f"Directory {dataset_path} not found")
#    1472 if fs.isfile(posixpath.join(dataset_path, config.DATASET_INFO_FILENAME)) and fs.isfile(
#    1473     posixpath.join(dataset_path, config.DATASET_STATE_JSON_FILENAME)
#    1474 ):
#    1475     return Dataset.load_from_disk(dataset_path, keep_in_memory=keep_in_memory, storage_options=storage_options)
#
# FileNotFoundError: Directory ./musiccaps/dataset_audio not found

# %%
print(sample.keys())
# Out:
# dict_keys(['ytid', 'start_s', 'end_s', 'audioset_positive_labels', 'aspect_list', 'caption', 'author_id', 'is_balanced_subset', 'is_audioset_eval', 'audio'])

# %%
caption = sample["caption"]
print(caption)
# Out:
# The low quality recording features a ballad song that contains sustained strings, mellow piano melody and soft female vocal singing over it. It sounds sad and soulful, like something you would hear at Sunday services.

# %%
audio = sample["audio"]

waveform = audio["array"]
sr = audio["sampling_rate"]

# %%
from IPython.display import Audio

audio = sample["audio"]

Audio(
    data=audio["array"],
    rate=audio["sampling_rate"]
)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample2 = ds[1500]
caption = sample2["caption"]
print(caption)

audio = sample2["audio"]

Audio(
    data=audio["array"],
    rate=audio["sampling_rate"]
)
# Out:
# The low quality recording features an ambient song that consists of mellow wide bells and wide low synth pad playing in the background. It sounds calming, relaxing and hypnotic, like something you would hear in a hypnotic therapy session.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
